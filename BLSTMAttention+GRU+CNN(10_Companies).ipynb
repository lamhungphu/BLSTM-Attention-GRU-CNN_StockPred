# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
# %matplotlib inline
from matplotlib.pylab import rcParams
from datetime import datetime
import warnings
from pylab import rcParams
from sklearn.model_selection import train_test_split as split
import warnings
import itertools
warnings.filterwarnings("ignore")
from IPython import display
from matplotlib import pyplot
import os
import re
import plotly.express as px
import warnings
from matplotlib.patches import Patch

# %%
import os
fileList = os.listdir("/content/")
fileList
# Out:
# ['.config',
#  'TCEHY.csv',
#  'NFLX.csv',
#  'MSFT.csv',
#  'NVDA.csv',
#  'TSLA.csv',
#  'AMZN.csv',
#  'BIDU.csv',
#  'GOOG.csv',
#  'AAPL.csv',
#  'INTC.csv',
#  'sample_data']

# %%
#companyName != "" and companyName !="sample_data"
companyList = []
for file in fileList:
    companyName = file.split(".")[0]
    if  companyName != "" and companyName !="sample_data":
        companyList.append(companyName)
print(companyList)
# Out:
# ['TCEHY', 'NFLX', 'MSFT', 'NVDA', 'TSLA', 'AMZN', 'BIDU', 'GOOG', 'AAPL', 'INTC']

# %%
import pandas as pd
# First, we get the data
stockList = ['AMZN', 'NVDA','AAPL','BIDU','GOOG','INTC','MSFT','NFLX','TCEHY','TSLA']
df_ = {}
for i in stockList:
    df_[i] = pd.read_csv("/content/" + i + ".csv", index_col = 'Date')

# %%
from sklearn.model_selection import train_test_split
def split(dataframe, border, col):
    return dataframe.loc[:border,col], dataframe.loc[border:,col]

df_new = {}
for i in stockList:
    df_new[i] = {}
    # train / test split
    df_new[i]["Train"] = df_[i].query('Date <=  "2019-03-13"').reset_index(drop = False)
    df_new[i]["Test"]  = df_[i].query('Date >= "2019-03-13"').reset_index(drop = False)

# %%
for i in stockList:
  df_new[i]["Train"].drop(columns=['Open', 'High','Low','Adj Close','Volume'],inplace = True)
  df_new[i]["Test"].drop(columns=['Open', 'High','Low','Adj Close','Volume'],inplace = True)

# %%
df_new[i]["Train"]
# Out:
#             Date      Close
# 0     2012-01-03   1.872000
# 1     2012-01-04   1.847333
# 2     2012-01-05   1.808000
# 3     2012-01-06   1.794000
# 4     2012-01-09   1.816667
# ...          ...        ...
# 1804  2019-03-07  18.439333
# 1805  2019-03-08  18.942667
# 1806  2019-03-11  19.394667
# 1807  2019-03-12  18.890667
# 1808  2019-03-13  19.264000
#
# [1809 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
# Scaling the training set
transform_train = {}
transform_test = {}
scaler = {}

for num, i in enumerate(stockList):
    sc = MinMaxScaler(feature_range=(0,1))
    a0 = np.array(df_new[i]["Train"]['Close'])
    a1 = np.array(df_new[i]["Test"]['Close'])
    a0 = a0.reshape(a0.shape[0],1)
    a1 = a1.reshape(a1.shape[0],1)
    transform_train[i] = sc.fit_transform(a0)
    transform_test[i] = sc.fit_transform(a1)
    scaler[i] = sc

del a0
del a1

# %%
for i in transform_train.keys():
    print(i, transform_train[i].shape)
print("\n")
for i in transform_test.keys():
    print(i, transform_test[i].shape)
# Out:
# AMZN (1809, 1)
# NVDA (1809, 1)
# AAPL (1809, 1)
# BIDU (1809, 1)
# GOOG (1809, 1)
# INTC (1809, 1)
# MSFT (1809, 1)
# NFLX (1809, 1)
# TCEHY (1809, 1)
# TSLA (1809, 1)
#
#
# AMZN (453, 1)
# NVDA (453, 1)
# AAPL (453, 1)
# BIDU (453, 1)
# GOOG (453, 1)
# INTC (453, 1)
# MSFT (453, 1)
# NFLX (453, 1)
# TCEHY (453, 1)
# TSLA (453, 1)

# %%
trainset = {}
testset = {}
for j in stockList:
    trainset[j] = {}
    X_train = []
    y_train = []
    for i in range(10,1809):
        X_train.append(transform_train[j][i-10:i,0])
        y_train.append(transform_train[j][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset[j]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset[j]["y"] = y_train

    testset[j] = {}
    X_test = []
    y_test = []
    for i in range(10, 453):
        X_test.append(transform_test[j][i-10:i,0])
        y_test.append(transform_test[j][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset[j]["X"] = np.reshape(X_test, (X_test.shape[0], X_train.shape[1], 1))
    testset[j]["y"] = y_test

# %%
arr_buff = []
for i in stockList:
    buff = {}
    buff["X_train"] = trainset[i]["X"].shape
    buff["y_train"] = trainset[i]["y"].shape
    buff["X_test"] = testset[i]["X"].shape
    buff["y_test"] = testset[i]["y"].shape
    arr_buff.append(buff)

pd.DataFrame(arr_buff, index=stockList)
# Out:
#              X_train  y_train        X_test  y_test
# AMZN   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# NVDA   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# AAPL   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# BIDU   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# GOOG   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# INTC   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# MSFT   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# NFLX   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# TCEHY  (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# TSLA   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)

# %%
from random import random
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import metrics
from keras.layers import Input, Dense, LSTM, Conv1D, Dropout, Bidirectional, Multiply
from keras.models import Model
# from attention_utils import get_activations
from keras.layers import *
from keras.layers import LSTM
from keras.models import *
import numpy as np
import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(1234)
from keras import backend as K
from keras.layers import InputLayer
from keras.optimizers import Adam
from keras import layers
from keras.models import Model

# %%
class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name='attention_weight', shape=(input_shape[-1],1),
                               initializer='random_normal', trainable=True)
        self.b=self.add_weight(name='attention_bias', shape=(input_shape[1],1),
                               initializer='zeros', trainable=True)
        super(attention, self).build(input_shape)

    def call(self,x):
        # Alignment scores. Pass them through tanh function
        e = K.tanh(K.dot(x,self.W)+self.b)
        # Remove dimension of size 1
        e = K.squeeze(e, axis=-1)
        # Compute the weights
        alpha = K.softmax(e)
        # Reshape to tensorFlow format
        alpha = K.expand_dims(alpha, axis=-1)
        # Compute the context vector
        context = x * alpha
        context = K.sum(context, axis=1)
        return context

# %%
time_steps = 10
n_features = 1
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, Conv1D, Dropout, Bidirectional, Multiply

def create_RNN_with_attention(input_shape):
    inputs = Input(shape=input_shape)
    x = Conv1D(filters=256, kernel_size=1, activation='relu')(inputs)
    bi1 = Bidirectional(LSTM(128, activation='relu', return_sequences=True))(x)
    dropout= Dropout(0.2)(bi1)
    gru = tf.keras.layers.GRU(128,activation='relu', return_sequences=True)(dropout)
    dropout1= Dropout(0.2)(gru)
    attention_layer = attention()(dropout1)
    dense1=Dense(64)(attention_layer)
    dense2=Dense(32)(dense1)
    dense3=Dense(1)(dense2)
    model=Model([inputs],dense3)
    model.compile(loss='mse', optimizer='adam')
    return model

model = create_RNN_with_attention(input_shape=(time_steps,1))
model.summary()
model.compile(optimizer = 'adam',loss = 'mse')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 1)]           0
#
#  conv1d (Conv1D)             (None, 10, 256)           512
#
#  bidirectional (Bidirection  (None, 10, 256)           394240
#  al)
#
#  dropout (Dropout)           (None, 10, 256)           0
#
#  gru (GRU)                   (None, 10, 128)           148224
#
#  dropout_1 (Dropout)         (None, 10, 128)           0
#
#  attention (attention)       (None, 128)               138
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 553483 (2.11 MB)
# Trainable params: 553483 (2.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
for i in stockList:
    print("Fitting to", i)
    history = model.fit(trainset[i]["X"], trainset[i]["y"], epochs=150, batch_size=32, validation_split=0.2)
# Out:
# Fitting to AMZN
# Epoch 1/150
# 45/45 [==============================] - 11s 107ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 2/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.9930e-04 - val_loss: 0.0013
# Epoch 3/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.6966e-04 - val_loss: 0.0013
# Epoch 4/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.3843e-04 - val_loss: 0.0013
# Epoch 5/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.4853e-04 - val_loss: 0.0013
# Epoch 6/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.3053e-04 - val_loss: 0.0013
# Epoch 7/150
# 45/45 [==============================] - 5s 105ms/step - loss: 1.4496e-04 - val_loss: 0.0012
# Epoch 8/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.8824e-04 - val_loss: 0.0012
# Epoch 9/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.3250e-04 - val_loss: 0.0016
# Epoch 10/150
# 45/45 [==============================] - 6s 125ms/step - loss: 1.7662e-04 - val_loss: 0.0016
# Epoch 11/150
# 45/45 [==============================] - 4s 90ms/step - loss: 1.6661e-04 - val_loss: 0.0012
# Epoch 12/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.5136e-04 - val_loss: 0.0012
# Epoch 13/150
# 45/45 [==============================] - 4s 88ms/step - loss: 1.3173e-04 - val_loss: 0.0012
# Epoch 14/150
# 45/45 [==============================] - 4s 93ms/step - loss: 1.4258e-04 - val_loss: 0.0014
# Epoch 15/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.5240e-04 - val_loss: 0.0027
# Epoch 16/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.8165e-04 - val_loss: 0.0011
# Epoch 17/150
# 45/45 [==============================] - 5s 119ms/step - loss: 1.3703e-04 - val_loss: 0.0015
# Epoch 18/150
# 45/45 [==============================] - 3s 76ms/step - loss: 2.0642e-04 - val_loss: 0.0014
# Epoch 19/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.6839e-04 - val_loss: 0.0011
# Epoch 20/150
# 45/45 [==============================] - 5s 110ms/step - loss: 1.2881e-04 - val_loss: 0.0010
# Epoch 21/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.2753e-04 - val_loss: 0.0010
# Epoch 22/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.3741e-04 - val_loss: 0.0014
# Epoch 23/150
# 45/45 [==============================] - 4s 90ms/step - loss: 1.1769e-04 - val_loss: 0.0016
# Epoch 24/150
# 45/45 [==============================] - 4s 91ms/step - loss: 1.3901e-04 - val_loss: 0.0011
# Epoch 25/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.2205e-04 - val_loss: 0.0015
# Epoch 26/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1995e-04 - val_loss: 0.0018
# Epoch 27/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.2403e-04 - val_loss: 9.3872e-04
# Epoch 28/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.2518e-04 - val_loss: 0.0017
# Epoch 29/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1681e-04 - val_loss: 9.1784e-04
# Epoch 30/150
# 45/45 [==============================] - 4s 96ms/step - loss: 1.3374e-04 - val_loss: 0.0033
# Epoch 31/150
# 45/45 [==============================] - 4s 85ms/step - loss: 1.3312e-04 - val_loss: 8.9519e-04
# Epoch 32/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.2855e-04 - val_loss: 8.8655e-04
# Epoch 33/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.4223e-04 - val_loss: 8.9093e-04
# Epoch 34/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.1985e-04 - val_loss: 0.0033
# Epoch 35/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.7105e-04 - val_loss: 0.0025
# Epoch 36/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.5185e-04 - val_loss: 9.3386e-04
# Epoch 37/150
# 45/45 [==============================] - 5s 104ms/step - loss: 1.5680e-04 - val_loss: 0.0023
# Epoch 38/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.1280e-04 - val_loss: 0.0014
# Epoch 39/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0906e-04 - val_loss: 0.0022
# Epoch 40/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.3276e-04 - val_loss: 8.2511e-04
# Epoch 41/150
# 45/45 [==============================] - 5s 100ms/step - loss: 1.0416e-04 - val_loss: 0.0037
# Epoch 42/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.2786e-04 - val_loss: 0.0011
# Epoch 43/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0007e-04 - val_loss: 0.0012
# Epoch 44/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.4158e-04 - val_loss: 0.0013
# Epoch 45/150
# 45/45 [==============================] - 3s 76ms/step - loss: 9.9339e-05 - val_loss: 0.0019
# Epoch 46/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.2816e-04 - val_loss: 0.0022
# Epoch 47/150
# 45/45 [==============================] - 4s 95ms/step - loss: 1.0721e-04 - val_loss: 7.9311e-04
# Epoch 48/150
# 45/45 [==============================] - 4s 87ms/step - loss: 1.1713e-04 - val_loss: 0.0013
# Epoch 49/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.3531e-04 - val_loss: 0.0048
# Epoch 50/150
# 45/45 [==============================] - 4s 94ms/step - loss: 1.2594e-04 - val_loss: 0.0024
# Epoch 51/150
# 45/45 [==============================] - 5s 118ms/step - loss: 1.3841e-04 - val_loss: 7.6518e-04
# Epoch 52/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.5624e-04 - val_loss: 0.0066
# Epoch 53/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.1490e-04 - val_loss: 0.0017
# Epoch 54/150
# 45/45 [==============================] - 5s 105ms/step - loss: 1.0239e-04 - val_loss: 0.0014
# Epoch 55/150
# 45/45 [==============================] - 4s 77ms/step - loss: 9.2763e-05 - val_loss: 0.0056
# Epoch 56/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1802e-04 - val_loss: 0.0023
# Epoch 57/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.0068e-04 - val_loss: 0.0016
# Epoch 58/150
# 45/45 [==============================] - 5s 102ms/step - loss: 9.5457e-05 - val_loss: 0.0012
# Epoch 59/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.8922e-05 - val_loss: 0.0039
# Epoch 60/150
# 45/45 [==============================] - 4s 78ms/step - loss: 9.5500e-05 - val_loss: 6.8450e-04
# Epoch 61/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.3345e-04 - val_loss: 0.0014
# Epoch 62/150
# 45/45 [==============================] - 4s 79ms/step - loss: 8.3155e-05 - val_loss: 9.0585e-04
# Epoch 63/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.1027e-05 - val_loss: 0.0027
# Epoch 64/150
# 45/45 [==============================] - 4s 89ms/step - loss: 9.8480e-05 - val_loss: 0.0036
# Epoch 65/150
# 45/45 [==============================] - 4s 91ms/step - loss: 1.1337e-04 - val_loss: 0.0033
# Epoch 66/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.0918e-04 - val_loss: 0.0031
# Epoch 67/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.9429e-05 - val_loss: 0.0023
# Epoch 68/150
# 45/45 [==============================] - 5s 106ms/step - loss: 9.4766e-05 - val_loss: 0.0025
# Epoch 69/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.7813e-05 - val_loss: 0.0023
# Epoch 70/150
# 45/45 [==============================] - 4s 79ms/step - loss: 8.7837e-05 - val_loss: 0.0010
# Epoch 71/150
# 45/45 [==============================] - 5s 104ms/step - loss: 8.2105e-05 - val_loss: 0.0016
# Epoch 72/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.5522e-04 - val_loss: 0.0012
# Epoch 73/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.0211e-04 - val_loss: 0.0015
# Epoch 74/150
# 45/45 [==============================] - 4s 86ms/step - loss: 1.1920e-04 - val_loss: 7.6025e-04
# Epoch 75/150
# 45/45 [==============================] - 4s 97ms/step - loss: 1.0447e-04 - val_loss: 0.0039
# Epoch 76/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0046e-04 - val_loss: 9.6873e-04
# Epoch 77/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.9483e-05 - val_loss: 0.0012
# Epoch 78/150
# 45/45 [==============================] - 5s 105ms/step - loss: 7.5810e-05 - val_loss: 8.8330e-04
# Epoch 79/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.7143e-05 - val_loss: 0.0012
# Epoch 80/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.0930e-04 - val_loss: 0.0024
# Epoch 81/150
# 45/45 [==============================] - 4s 96ms/step - loss: 8.2547e-05 - val_loss: 0.0026
# Epoch 82/150
# 45/45 [==============================] - 4s 86ms/step - loss: 1.1982e-04 - val_loss: 0.0018
# Epoch 83/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0363e-04 - val_loss: 0.0012
# Epoch 84/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.4357e-04 - val_loss: 0.0042
# Epoch 85/150
# 45/45 [==============================] - 5s 108ms/step - loss: 8.1171e-05 - val_loss: 0.0029
# Epoch 86/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.1842e-05 - val_loss: 0.0025
# Epoch 87/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.9473e-05 - val_loss: 0.0017
# Epoch 88/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.0378e-04 - val_loss: 0.0030
# Epoch 89/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.6397e-05 - val_loss: 0.0045
# Epoch 90/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.3180e-05 - val_loss: 0.0011
# Epoch 91/150
# 45/45 [==============================] - 4s 90ms/step - loss: 1.1356e-04 - val_loss: 6.9722e-04
# Epoch 92/150
# 45/45 [==============================] - 6s 125ms/step - loss: 1.2149e-04 - val_loss: 0.0027
# Epoch 93/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.5922e-05 - val_loss: 0.0013
# Epoch 94/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.7738e-05 - val_loss: 9.6937e-04
# Epoch 95/150
# 45/45 [==============================] - 4s 98ms/step - loss: 8.5389e-05 - val_loss: 0.0015
# Epoch 96/150
# 45/45 [==============================] - 4s 84ms/step - loss: 6.8124e-05 - val_loss: 0.0030
# Epoch 97/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.9317e-05 - val_loss: 0.0052
# Epoch 98/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.8684e-05 - val_loss: 0.0023
# Epoch 99/150
# 45/45 [==============================] - 5s 106ms/step - loss: 8.5109e-05 - val_loss: 0.0019
# Epoch 100/150
# 45/45 [==============================] - 3s 75ms/step - loss: 7.5449e-05 - val_loss: 0.0059
# Epoch 101/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.5585e-05 - val_loss: 0.0022
# Epoch 102/150
# 45/45 [==============================] - 5s 110ms/step - loss: 9.5212e-05 - val_loss: 0.0025
# Epoch 103/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.7484e-05 - val_loss: 0.0055
# Epoch 104/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.4977e-05 - val_loss: 0.0045
# Epoch 105/150
# 45/45 [==============================] - 4s 92ms/step - loss: 7.7998e-05 - val_loss: 0.0051
# Epoch 106/150
# 45/45 [==============================] - 4s 91ms/step - loss: 1.0001e-04 - val_loss: 0.0040
# Epoch 107/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.2450e-05 - val_loss: 0.0044
# Epoch 108/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.1031e-05 - val_loss: 0.0049
# Epoch 109/150
# 45/45 [==============================] - 5s 106ms/step - loss: 7.0174e-05 - val_loss: 0.0072
# Epoch 110/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.8339e-05 - val_loss: 0.0051
# Epoch 111/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.7708e-05 - val_loss: 0.0079
# Epoch 112/150
# 45/45 [==============================] - 5s 103ms/step - loss: 9.4353e-05 - val_loss: 0.0073
# Epoch 113/150
# 45/45 [==============================] - 4s 81ms/step - loss: 8.0178e-05 - val_loss: 0.0112
# Epoch 114/150
# 45/45 [==============================] - 3s 78ms/step - loss: 6.7160e-05 - val_loss: 0.0044
# Epoch 115/150
# 45/45 [==============================] - 4s 80ms/step - loss: 9.6296e-05 - val_loss: 0.0083
# Epoch 116/150
# 45/45 [==============================] - 5s 103ms/step - loss: 7.1444e-05 - val_loss: 0.0081
# Epoch 117/150
# 45/45 [==============================] - 4s 78ms/step - loss: 6.7938e-05 - val_loss: 0.0115
# Epoch 118/150
# 45/45 [==============================] - 4s 78ms/step - loss: 9.4444e-05 - val_loss: 0.0102
# Epoch 119/150
# 45/45 [==============================] - 5s 108ms/step - loss: 9.3608e-05 - val_loss: 0.0083
# Epoch 120/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.4616e-05 - val_loss: 0.0077
# Epoch 121/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.8764e-05 - val_loss: 0.0143
# Epoch 122/150
# 45/45 [==============================] - 4s 95ms/step - loss: 8.1466e-05 - val_loss: 0.0100
# Epoch 123/150
# 45/45 [==============================] - 4s 86ms/step - loss: 9.5710e-05 - val_loss: 0.0138
# Epoch 124/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.3507e-05 - val_loss: 0.0177
# Epoch 125/150
# 45/45 [==============================] - 3s 76ms/step - loss: 6.4546e-05 - val_loss: 0.0188
# Epoch 126/150
# 45/45 [==============================] - 5s 106ms/step - loss: 6.4391e-05 - val_loss: 0.0204
# Epoch 127/150
# 45/45 [==============================] - 3s 76ms/step - loss: 6.6399e-05 - val_loss: 0.0249
# Epoch 128/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.0689e-05 - val_loss: 0.0310
# Epoch 129/150
# 45/45 [==============================] - 5s 109ms/step - loss: 7.0578e-05 - val_loss: 0.0265
# Epoch 130/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.9173e-05 - val_loss: 0.0317
# Epoch 131/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.3888e-05 - val_loss: 0.0331
# Epoch 132/150
# 45/45 [==============================] - 4s 89ms/step - loss: 6.9022e-05 - val_loss: 0.0327
# Epoch 133/150
# 45/45 [==============================] - 6s 126ms/step - loss: 6.3574e-05 - val_loss: 0.0342
# Epoch 134/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.5564e-05 - val_loss: 0.0408
# Epoch 135/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.5995e-05 - val_loss: 0.0379
# Epoch 136/150
# 45/45 [==============================] - 5s 102ms/step - loss: 9.0481e-05 - val_loss: 0.0462
# Epoch 137/150
# 45/45 [==============================] - 4s 81ms/step - loss: 6.5678e-05 - val_loss: 0.0448
# Epoch 138/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.6964e-05 - val_loss: 0.0402
# Epoch 139/150
# 45/45 [==============================] - 4s 86ms/step - loss: 7.2120e-05 - val_loss: 0.0484
# Epoch 140/150
# 45/45 [==============================] - 4s 98ms/step - loss: 8.2407e-05 - val_loss: 0.0435
# Epoch 141/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.0956e-05 - val_loss: 0.0410
# Epoch 142/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.5411e-05 - val_loss: 0.0454
# Epoch 143/150
# 45/45 [==============================] - 5s 109ms/step - loss: 8.6927e-05 - val_loss: 0.0490
# Epoch 144/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.3284e-05 - val_loss: 0.0436
# Epoch 145/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.0993e-05 - val_loss: 0.0403
# Epoch 146/150
# 45/45 [==============================] - 5s 103ms/step - loss: 9.9528e-05 - val_loss: 0.0532
# Epoch 147/150
# 45/45 [==============================] - 4s 83ms/step - loss: 8.8769e-05 - val_loss: 0.0508
# Epoch 148/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.0979e-05 - val_loss: 0.0532
# Epoch 149/150
# 45/45 [==============================] - 4s 87ms/step - loss: 7.8443e-05 - val_loss: 0.0467
# Epoch 150/150
# 45/45 [==============================] - 4s 96ms/step - loss: 7.4148e-05 - val_loss: 0.0426
# Fitting to NVDA
# Epoch 1/150
# 45/45 [==============================] - 4s 81ms/step - loss: 1.0644e-04 - val_loss: 0.0104
# Epoch 2/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.2640e-04 - val_loss: 0.0173
# Epoch 3/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.4815e-04 - val_loss: 0.0048
# Epoch 4/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.7655e-04 - val_loss: 0.0082
# Epoch 5/150
# 45/45 [==============================] - 4s 93ms/step - loss: 9.3222e-05 - val_loss: 0.0080
# Epoch 6/150
# 45/45 [==============================] - 4s 92ms/step - loss: 1.0504e-04 - val_loss: 0.0110
# Epoch 7/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.4289e-04 - val_loss: 0.0110
# Epoch 8/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.2113e-04 - val_loss: 0.0053
# Epoch 9/150
# 45/45 [==============================] - 5s 108ms/step - loss: 9.5556e-05 - val_loss: 0.0089
# Epoch 10/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.6431e-04 - val_loss: 0.0034
# Epoch 11/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.4642e-04 - val_loss: 0.0088
# Epoch 12/150
# 45/45 [==============================] - 5s 109ms/step - loss: 1.2039e-04 - val_loss: 0.0052
# Epoch 13/150
# 45/45 [==============================] - 4s 87ms/step - loss: 1.2871e-04 - val_loss: 0.0063
# Epoch 14/150
# 45/45 [==============================] - 4s 97ms/step - loss: 1.2124e-04 - val_loss: 0.0043
# Epoch 15/150
# 45/45 [==============================] - 5s 107ms/step - loss: 7.7504e-05 - val_loss: 0.0078
# Epoch 16/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0274e-04 - val_loss: 0.0072
# Epoch 17/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.7504e-05 - val_loss: 0.0129
# Epoch 18/150
# 45/45 [==============================] - 4s 92ms/step - loss: 9.5920e-05 - val_loss: 0.0070
# Epoch 19/150
# 45/45 [==============================] - 4s 92ms/step - loss: 7.5120e-05 - val_loss: 0.0155
# Epoch 20/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.8915e-05 - val_loss: 0.0127
# Epoch 21/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.0501e-04 - val_loss: 0.0131
# Epoch 22/150
# 45/45 [==============================] - 5s 106ms/step - loss: 9.4861e-05 - val_loss: 0.0090
# Epoch 23/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.9116e-05 - val_loss: 0.0088
# Epoch 24/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1295e-04 - val_loss: 0.0057
# Epoch 25/150
# 45/45 [==============================] - 4s 100ms/step - loss: 9.8359e-05 - val_loss: 0.0076
# Epoch 26/150
# 45/45 [==============================] - 4s 85ms/step - loss: 9.5767e-05 - val_loss: 0.0088
# Epoch 27/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.7456e-05 - val_loss: 0.0115
# Epoch 28/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.0981e-04 - val_loss: 0.0075
# Epoch 29/150
# 45/45 [==============================] - 5s 103ms/step - loss: 9.0581e-05 - val_loss: 0.0088
# Epoch 30/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.4880e-04 - val_loss: 0.0043
# Epoch 31/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.9228e-05 - val_loss: 0.0057
# Epoch 32/150
# 45/45 [==============================] - 5s 108ms/step - loss: 1.0229e-04 - val_loss: 0.0087
# Epoch 33/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.2238e-04 - val_loss: 0.0033
# Epoch 34/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.1035e-04 - val_loss: 0.0042
# Epoch 35/150
# 45/45 [==============================] - 4s 96ms/step - loss: 1.0654e-04 - val_loss: 0.0070
# Epoch 36/150
# 45/45 [==============================] - 4s 88ms/step - loss: 8.1191e-05 - val_loss: 0.0048
# Epoch 37/150
# 45/45 [==============================] - 4s 79ms/step - loss: 9.6705e-05 - val_loss: 0.0052
# Epoch 38/150
# 45/45 [==============================] - 4s 78ms/step - loss: 9.2670e-05 - val_loss: 0.0083
# Epoch 39/150
# 45/45 [==============================] - 5s 107ms/step - loss: 6.7065e-05 - val_loss: 0.0094
# Epoch 40/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.0936e-04 - val_loss: 0.0078
# Epoch 41/150
# 45/45 [==============================] - 4s 78ms/step - loss: 9.9698e-05 - val_loss: 0.0087
# Epoch 42/150
# 45/45 [==============================] - 5s 107ms/step - loss: 9.4830e-05 - val_loss: 0.0070
# Epoch 43/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0550e-04 - val_loss: 0.0031
# Epoch 44/150
# 45/45 [==============================] - 4s 78ms/step - loss: 8.6727e-05 - val_loss: 0.0055
# Epoch 45/150
# 45/45 [==============================] - 4s 92ms/step - loss: 7.8384e-05 - val_loss: 0.0041
# Epoch 46/150
# 45/45 [==============================] - 4s 92ms/step - loss: 1.5169e-04 - val_loss: 0.0106
# Epoch 47/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1925e-04 - val_loss: 0.0093
# Epoch 48/150
# 45/45 [==============================] - 4s 78ms/step - loss: 8.3926e-05 - val_loss: 0.0101
# Epoch 49/150
# 45/45 [==============================] - 5s 110ms/step - loss: 8.1095e-05 - val_loss: 0.0065
# Epoch 50/150
# 45/45 [==============================] - 3s 76ms/step - loss: 7.0377e-05 - val_loss: 0.0091
# Epoch 51/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.1440e-04 - val_loss: 0.0099
# Epoch 52/150
# 45/45 [==============================] - 5s 107ms/step - loss: 8.3323e-05 - val_loss: 0.0098
# Epoch 53/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.3745e-05 - val_loss: 0.0134
# Epoch 54/150
# 45/45 [==============================] - 4s 89ms/step - loss: 9.4071e-05 - val_loss: 0.0101
# Epoch 55/150
# 45/45 [==============================] - 6s 127ms/step - loss: 1.0048e-04 - val_loss: 0.0163
# Epoch 56/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1775e-04 - val_loss: 0.0062
# Epoch 57/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.9630e-05 - val_loss: 0.0058
# Epoch 58/150
# 45/45 [==============================] - 4s 87ms/step - loss: 9.3808e-05 - val_loss: 0.0060
# Epoch 59/150
# 45/45 [==============================] - 4s 95ms/step - loss: 1.1710e-04 - val_loss: 0.0053
# Epoch 60/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.0661e-04 - val_loss: 0.0114
# Epoch 61/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.8526e-05 - val_loss: 0.0051
# Epoch 62/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.0795e-04 - val_loss: 0.0047
# Epoch 63/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.8657e-05 - val_loss: 0.0079
# Epoch 64/150
# 45/45 [==============================] - 3s 76ms/step - loss: 9.5647e-05 - val_loss: 0.0059
# Epoch 65/150
# 45/45 [==============================] - 4s 98ms/step - loss: 7.9009e-05 - val_loss: 0.0091
# Epoch 66/150
# 45/45 [==============================] - 4s 84ms/step - loss: 1.0351e-04 - val_loss: 0.0050
# Epoch 67/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.2596e-04 - val_loss: 0.0069
# Epoch 68/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.0437e-05 - val_loss: 0.0080
# Epoch 69/150
# 45/45 [==============================] - 5s 107ms/step - loss: 8.2844e-05 - val_loss: 0.0053
# Epoch 70/150
# 45/45 [==============================] - 3s 76ms/step - loss: 9.1807e-05 - val_loss: 0.0066
# Epoch 71/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.6214e-05 - val_loss: 0.0042
# Epoch 72/150
# 45/45 [==============================] - 5s 106ms/step - loss: 8.6284e-05 - val_loss: 0.0035
# Epoch 73/150
# 45/45 [==============================] - 3s 76ms/step - loss: 9.9193e-05 - val_loss: 0.0034
# Epoch 74/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.3337e-04 - val_loss: 0.0150
# Epoch 75/150
# 45/45 [==============================] - 4s 88ms/step - loss: 1.2054e-04 - val_loss: 0.0097
# Epoch 76/150
# 45/45 [==============================] - 4s 95ms/step - loss: 9.8236e-05 - val_loss: 0.0042
# Epoch 77/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.2129e-05 - val_loss: 0.0049
# Epoch 78/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.2567e-05 - val_loss: 0.0091
# Epoch 79/150
# 45/45 [==============================] - 5s 108ms/step - loss: 8.2919e-05 - val_loss: 0.0029
# Epoch 80/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.0081e-04 - val_loss: 0.0015
# Epoch 81/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.7650e-05 - val_loss: 0.0070
# Epoch 82/150
# 45/45 [==============================] - 5s 101ms/step - loss: 7.7010e-05 - val_loss: 0.0066
# Epoch 83/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.2180e-04 - val_loss: 0.0031
# Epoch 84/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.0983e-05 - val_loss: 0.0049
# Epoch 85/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.0564e-04 - val_loss: 0.0058
# Epoch 86/150
# 45/45 [==============================] - 5s 106ms/step - loss: 7.2337e-05 - val_loss: 0.0087
# Epoch 87/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.2562e-04 - val_loss: 0.0062
# Epoch 88/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.0809e-04 - val_loss: 0.0058
# Epoch 89/150
# 45/45 [==============================] - 5s 112ms/step - loss: 7.8773e-05 - val_loss: 0.0035
# Epoch 90/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.2766e-05 - val_loss: 0.0122
# Epoch 91/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.2140e-05 - val_loss: 0.0061
# Epoch 92/150
# 45/45 [==============================] - 4s 95ms/step - loss: 7.3882e-05 - val_loss: 0.0113
# Epoch 93/150
# 45/45 [==============================] - 4s 89ms/step - loss: 6.6517e-05 - val_loss: 0.0046
# Epoch 94/150
# 45/45 [==============================] - 4s 80ms/step - loss: 9.1932e-05 - val_loss: 0.0040
# Epoch 95/150
# 45/45 [==============================] - 4s 80ms/step - loss: 8.4623e-05 - val_loss: 0.0037
# Epoch 96/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.0471e-04 - val_loss: 0.0027
# Epoch 97/150
# 45/45 [==============================] - 5s 107ms/step - loss: 8.3292e-05 - val_loss: 0.0044
# Epoch 98/150
# 45/45 [==============================] - 3s 76ms/step - loss: 8.6928e-05 - val_loss: 0.0049
# Epoch 99/150
# 45/45 [==============================] - 5s 107ms/step - loss: 8.4266e-05 - val_loss: 0.0043
# Epoch 100/150
# 45/45 [==============================] - 3s 78ms/step - loss: 9.2279e-05 - val_loss: 0.0031
# Epoch 101/150
# 45/45 [==============================] - 3s 78ms/step - loss: 7.6177e-05 - val_loss: 0.0048
# Epoch 102/150
# 45/45 [==============================] - 5s 108ms/step - loss: 8.6874e-05 - val_loss: 0.0029
# Epoch 103/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.9718e-05 - val_loss: 0.0066
# Epoch 104/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.5029e-05 - val_loss: 0.0078
# Epoch 105/150
# 45/45 [==============================] - 4s 85ms/step - loss: 9.2101e-05 - val_loss: 0.0054
# Epoch 106/150
# 45/45 [==============================] - 4s 98ms/step - loss: 8.6687e-05 - val_loss: 0.0053
# Epoch 107/150
# 45/45 [==============================] - 4s 79ms/step - loss: 7.5796e-05 - val_loss: 0.0038
# Epoch 108/150
# 45/45 [==============================] - 3s 77ms/step - loss: 8.0784e-05 - val_loss: 0.0078
# Epoch 109/150
# 45/45 [==============================] - 5s 107ms/step - loss: 8.4152e-05 - val_loss: 0.0058
# Epoch 110/150
# 45/45 [==============================] - 4s 78ms/step - loss: 9.0897e-05 - val_loss: 0.0040
# Epoch 111/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.1160e-05 - val_loss: 0.0043
# Epoch 112/150
# 45/45 [==============================] - 5s 103ms/step - loss: 8.2410e-05 - val_loss: 0.0052
# Epoch 113/150
# 45/45 [==============================] - 4s 82ms/step - loss: 7.7977e-05 - val_loss: 0.0064
# Epoch 114/150
# 45/45 [==============================] - 4s 79ms/step - loss: 8.4012e-05 - val_loss: 0.0071
# Epoch 115/150
# 45/45 [==============================] - 4s 87ms/step - loss: 7.1355e-05 - val_loss: 0.0047
# Epoch 116/150
# 45/45 [==============================] - 4s 97ms/step - loss: 1.2112e-04 - val_loss: 0.0075
# Epoch 117/150
# 45/45 [==============================] - 3s 77ms/step - loss: 7.2850e-05 - val_loss: 0.0054
# Epoch 118/150
# 45/45 [==============================] - 4s 78ms/step - loss: 6.6267e-05 - val_loss: 0.0053
# Epoch 119/150
# 45/45 [==============================] - 5s 107ms/step - loss: 6.8184e-05 - val_loss: 0.0092
# Epoch 120/150
# 45/45 [==============================] - 3s 78ms/step - loss: 7.5244e-05 - val_loss: 0.0080
# Epoch 121/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.5724e-05 - val_loss: 0.0030
# Epoch 122/150
# 45/45 [==============================] - 5s 103ms/step - loss: 8.1498e-05 - val_loss: 0.0056
# Epoch 123/150
# 45/45 [==============================] - 4s 81ms/step - loss: 8.6236e-05 - val_loss: 0.0074
# Epoch 124/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.0466e-05 - val_loss: 0.0057
# Epoch 125/150
# 45/45 [==============================] - 4s 81ms/step - loss: 1.4153e-04 - val_loss: 0.0030
# Epoch 126/150
# 45/45 [==============================] - 5s 102ms/step - loss: 8.3401e-05 - val_loss: 0.0078
# Epoch 127/150
# 45/45 [==============================] - 3s 78ms/step - loss: 7.0474e-05 - val_loss: 0.0101
# Epoch 128/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.6076e-05 - val_loss: 0.0053
# Epoch 129/150
# 45/45 [==============================] - 5s 107ms/step - loss: 6.9631e-05 - val_loss: 0.0075
# Epoch 130/150
# 45/45 [==============================] - 4s 78ms/step - loss: 9.0837e-05 - val_loss: 0.0102
# Epoch 131/150
# 45/45 [==============================] - 4s 79ms/step - loss: 9.8604e-05 - val_loss: 0.0064
# Epoch 132/150
# 45/45 [==============================] - 4s 91ms/step - loss: 8.0018e-05 - val_loss: 0.0067
# Epoch 133/150
# 45/45 [==============================] - 4s 92ms/step - loss: 1.0768e-04 - val_loss: 0.0104
# Epoch 134/150
# 45/45 [==============================] - 4s 78ms/step - loss: 7.8340e-05 - val_loss: 0.0058
# Epoch 135/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1802e-04 - val_loss: 0.0092
# Epoch 136/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.0142e-04 - val_loss: 0.0034
# Epoch 137/150
# 45/45 [==============================] - 4s 79ms/step - loss: 7.3975e-05 - val_loss: 0.0031
# Epoch 138/150
# 45/45 [==============================] - 4s 94ms/step - loss: 8.1118e-05 - val_loss: 0.0060
# Epoch 139/150
# 45/45 [==============================] - 5s 120ms/step - loss: 7.2720e-05 - val_loss: 0.0058
# Epoch 140/150
# 45/45 [==============================] - 4s 78ms/step - loss: 6.5478e-05 - val_loss: 0.0092
# Epoch 141/150
# 45/45 [==============================] - 4s 79ms/step - loss: 8.3909e-05 - val_loss: 0.0075
# Epoch 142/150
# 45/45 [==============================] - 4s 100ms/step - loss: 9.6039e-05 - val_loss: 0.0059
# Epoch 143/150
# 45/45 [==============================] - 4s 82ms/step - loss: 7.8506e-05 - val_loss: 0.0066
# Epoch 144/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.3532e-05 - val_loss: 0.0061
# Epoch 145/150
# 45/45 [==============================] - 4s 80ms/step - loss: 6.2409e-05 - val_loss: 0.0088
# Epoch 146/150
# 45/45 [==============================] - 5s 103ms/step - loss: 1.2298e-04 - val_loss: 0.0108
# Epoch 147/150
# 45/45 [==============================] - 3s 78ms/step - loss: 8.5887e-05 - val_loss: 0.0095
# Epoch 148/150
# 45/45 [==============================] - 3s 77ms/step - loss: 9.6931e-05 - val_loss: 0.0126
# Epoch 149/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.0188e-04 - val_loss: 0.0111
# Epoch 150/150
# 45/45 [==============================] - 4s 78ms/step - loss: 7.8851e-05 - val_loss: 0.0043
# Fitting to AAPL
# Epoch 1/150
# 45/45 [==============================] - 4s 79ms/step - loss: 2.5458e-04 - val_loss: 0.0049
# Epoch 2/150
# 45/45 [==============================] - 4s 91ms/step - loss: 1.9849e-04 - val_loss: 0.0050
# Epoch 3/150
# 45/45 [==============================] - 4s 92ms/step - loss: 1.9463e-04 - val_loss: 0.0028
# Epoch 4/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.6436e-04 - val_loss: 0.0047
# Epoch 5/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.8083e-04 - val_loss: 0.0034
# Epoch 6/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.7570e-04 - val_loss: 0.0062
# Epoch 7/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.3966e-04 - val_loss: 0.0047
# Epoch 8/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.5021e-04 - val_loss: 0.0050
# Epoch 9/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.7822e-04 - val_loss: 0.0048
# Epoch 10/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.6064e-04 - val_loss: 0.0073
# Epoch 11/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.8080e-04 - val_loss: 0.0090
# Epoch 12/150
# 45/45 [==============================] - 4s 86ms/step - loss: 1.4218e-04 - val_loss: 0.0052
# Epoch 13/150
# 45/45 [==============================] - 4s 97ms/step - loss: 1.4848e-04 - val_loss: 0.0083
# Epoch 14/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.4174e-04 - val_loss: 0.0051
# Epoch 15/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.5118e-04 - val_loss: 0.0063
# Epoch 16/150
# 45/45 [==============================] - 5s 109ms/step - loss: 1.6236e-04 - val_loss: 0.0079
# Epoch 17/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.4361e-04 - val_loss: 0.0078
# Epoch 18/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.3696e-04 - val_loss: 0.0061
# Epoch 19/150
# 45/45 [==============================] - 5s 104ms/step - loss: 1.5410e-04 - val_loss: 0.0083
# Epoch 20/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.4020e-04 - val_loss: 0.0064
# Epoch 21/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.4969e-04 - val_loss: 0.0080
# Epoch 22/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.6735e-04 - val_loss: 0.0092
# Epoch 23/150
# 45/45 [==============================] - 5s 104ms/step - loss: 1.3841e-04 - val_loss: 0.0050
# Epoch 24/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.3507e-04 - val_loss: 0.0096
# Epoch 25/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.5696e-04 - val_loss: 0.0090
# Epoch 26/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.2145e-04 - val_loss: 0.0085
# Epoch 27/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.3739e-04 - val_loss: 0.0089
# Epoch 28/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.3889e-04 - val_loss: 0.0072
# Epoch 29/150
# 45/45 [==============================] - 5s 102ms/step - loss: 1.5042e-04 - val_loss: 0.0089
# Epoch 30/150
# 45/45 [==============================] - 5s 113ms/step - loss: 1.3173e-04 - val_loss: 0.0065
# Epoch 31/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.9898e-04 - val_loss: 0.0135
# Epoch 32/150
# 45/45 [==============================] - 4s 98ms/step - loss: 1.4065e-04 - val_loss: 0.0065
# Epoch 33/150
# 45/45 [==============================] - 4s 86ms/step - loss: 1.4105e-04 - val_loss: 0.0098
# Epoch 34/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.3508e-04 - val_loss: 0.0098
# Epoch 35/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.3222e-04 - val_loss: 0.0101
# Epoch 36/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.3152e-04 - val_loss: 0.0119
# Epoch 37/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.2878e-04 - val_loss: 0.0083
# Epoch 38/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2997e-04 - val_loss: 0.0093
# Epoch 39/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.2632e-04 - val_loss: 0.0068
# Epoch 40/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.4260e-04 - val_loss: 0.0092
# Epoch 41/150
# 45/45 [==============================] - 3s 78ms/step - loss: 1.2968e-04 - val_loss: 0.0063
# Epoch 42/150
# 45/45 [==============================] - 4s 97ms/step - loss: 1.3497e-04 - val_loss: 0.0081
# Epoch 43/150
# 45/45 [==============================] - 4s 87ms/step - loss: 1.2656e-04 - val_loss: 0.0124
# Epoch 44/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.4859e-04 - val_loss: 0.0128
# Epoch 45/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.4541e-04 - val_loss: 0.0110
# Epoch 46/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.5982e-04 - val_loss: 0.0125
# Epoch 47/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.4577e-04 - val_loss: 0.0084
# Epoch 48/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2170e-04 - val_loss: 0.0089
# Epoch 49/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.3304e-04 - val_loss: 0.0088
# Epoch 50/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.1979e-04 - val_loss: 0.0124
# Epoch 51/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.4217e-04 - val_loss: 0.0101
# Epoch 52/150
# 45/45 [==============================] - 4s 94ms/step - loss: 1.4414e-04 - val_loss: 0.0085
# Epoch 53/150
# 45/45 [==============================] - 4s 92ms/step - loss: 1.5072e-04 - val_loss: 0.0142
# Epoch 54/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.4791e-04 - val_loss: 0.0104
# Epoch 55/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.3041e-04 - val_loss: 0.0089
# Epoch 56/150
# 45/45 [==============================] - 5s 108ms/step - loss: 1.4421e-04 - val_loss: 0.0116
# Epoch 57/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.3299e-04 - val_loss: 0.0122
# Epoch 58/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.3032e-04 - val_loss: 0.0101
# Epoch 59/150
# 45/45 [==============================] - 5s 109ms/step - loss: 1.1785e-04 - val_loss: 0.0078
# Epoch 60/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.4343e-04 - val_loss: 0.0102
# Epoch 61/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2948e-04 - val_loss: 0.0082
# Epoch 62/150
# 45/45 [==============================] - 5s 101ms/step - loss: 1.2375e-04 - val_loss: 0.0099
# Epoch 63/150
# 45/45 [==============================] - 4s 88ms/step - loss: 1.3395e-04 - val_loss: 0.0112
# Epoch 64/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.3754e-04 - val_loss: 0.0111
# Epoch 65/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1679e-04 - val_loss: 0.0130
# Epoch 66/150
# 45/45 [==============================] - 5s 106ms/step - loss: 1.3051e-04 - val_loss: 0.0085
# Epoch 67/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2194e-04 - val_loss: 0.0095
# Epoch 68/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1449e-04 - val_loss: 0.0117
# Epoch 69/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.1850e-04 - val_loss: 0.0099
# Epoch 70/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2388e-04 - val_loss: 0.0105
# Epoch 71/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.1223e-04 - val_loss: 0.0090
# Epoch 72/150
# 45/45 [==============================] - 6s 133ms/step - loss: 1.4224e-04 - val_loss: 0.0112
# Epoch 73/150
# 45/45 [==============================] - 4s 84ms/step - loss: 1.2229e-04 - val_loss: 0.0085
# Epoch 74/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2253e-04 - val_loss: 0.0076
# Epoch 75/150
# 45/45 [==============================] - 4s 83ms/step - loss: 1.3065e-04 - val_loss: 0.0107
# Epoch 76/150
# 45/45 [==============================] - 5s 104ms/step - loss: 1.2757e-04 - val_loss: 0.0073
# Epoch 77/150
# 45/45 [==============================] - 4s 78ms/step - loss: 1.1708e-04 - val_loss: 0.0077
# Epoch 78/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.1828e-04 - val_loss: 0.0106
# Epoch 79/150
# 45/45 [==============================] - 5s 109ms/step - loss: 1.1481e-04 - val_loss: 0.0077
# Epoch 80/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.3410e-04 - val_loss: 0.0082
# Epoch 81/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2698e-04 - val_loss: 0.0082
# Epoch 82/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.1096e-04 - val_loss: 0.0122
# Epoch 83/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.1747e-04 - val_loss: 0.0088
# Epoch 84/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.1101e-04 - val_loss: 0.0075
# Epoch 85/150
# 45/45 [==============================] - 4s 94ms/step - loss: 1.2394e-04 - val_loss: 0.0094
# Epoch 86/150
# 45/45 [==============================] - 4s 94ms/step - loss: 1.2028e-04 - val_loss: 0.0097
# Epoch 87/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.1533e-04 - val_loss: 0.0118
# Epoch 88/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2902e-04 - val_loss: 0.0104
# Epoch 89/150
# 45/45 [==============================] - 5s 109ms/step - loss: 1.2744e-04 - val_loss: 0.0098
# Epoch 90/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2550e-04 - val_loss: 0.0087
# Epoch 91/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2752e-04 - val_loss: 0.0119
# Epoch 92/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.2843e-04 - val_loss: 0.0095
# Epoch 93/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.5424e-04 - val_loss: 0.0100
# Epoch 94/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2506e-04 - val_loss: 0.0092
# Epoch 95/150
# 45/45 [==============================] - 4s 89ms/step - loss: 1.2997e-04 - val_loss: 0.0115
# Epoch 96/150
# 45/45 [==============================] - 4s 97ms/step - loss: 1.3113e-04 - val_loss: 0.0122
# Epoch 97/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.1878e-04 - val_loss: 0.0091
# Epoch 98/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.3035e-04 - val_loss: 0.0110
# Epoch 99/150
# 45/45 [==============================] - 5s 110ms/step - loss: 1.3251e-04 - val_loss: 0.0114
# Epoch 100/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2283e-04 - val_loss: 0.0072
# Epoch 101/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1438e-04 - val_loss: 0.0083
# Epoch 102/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.1723e-04 - val_loss: 0.0100
# Epoch 103/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2341e-04 - val_loss: 0.0089
# Epoch 104/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2397e-04 - val_loss: 0.0099
# Epoch 105/150
# 45/45 [==============================] - 4s 88ms/step - loss: 1.1145e-04 - val_loss: 0.0105
# Epoch 106/150
# 45/45 [==============================] - 4s 98ms/step - loss: 1.1940e-04 - val_loss: 0.0095
# Epoch 107/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.1959e-04 - val_loss: 0.0082
# Epoch 108/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1194e-04 - val_loss: 0.0134
# Epoch 109/150
# 45/45 [==============================] - 5s 109ms/step - loss: 1.3483e-04 - val_loss: 0.0119
# Epoch 110/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1865e-04 - val_loss: 0.0111
# Epoch 111/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2083e-04 - val_loss: 0.0093
# Epoch 112/150
# 45/45 [==============================] - 5s 110ms/step - loss: 1.1098e-04 - val_loss: 0.0117
# Epoch 113/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.4158e-04 - val_loss: 0.0152
# Epoch 114/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.3257e-04 - val_loss: 0.0074
# Epoch 115/150
# 45/45 [==============================] - 5s 102ms/step - loss: 1.3634e-04 - val_loss: 0.0090
# Epoch 116/150
# 45/45 [==============================] - 4s 87ms/step - loss: 1.1358e-04 - val_loss: 0.0090
# Epoch 117/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.0836e-04 - val_loss: 0.0100
# Epoch 118/150
# 45/45 [==============================] - 4s 81ms/step - loss: 1.3876e-04 - val_loss: 0.0107
# Epoch 119/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.1375e-04 - val_loss: 0.0113
# Epoch 120/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.1242e-04 - val_loss: 0.0081
# Epoch 121/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.0766e-04 - val_loss: 0.0105
# Epoch 122/150
# 45/45 [==============================] - 5s 110ms/step - loss: 1.1043e-04 - val_loss: 0.0122
# Epoch 123/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1166e-04 - val_loss: 0.0128
# Epoch 124/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.0782e-04 - val_loss: 0.0119
# Epoch 125/150
# 45/45 [==============================] - 4s 99ms/step - loss: 1.3417e-04 - val_loss: 0.0120
# Epoch 126/150
# 45/45 [==============================] - 5s 120ms/step - loss: 1.3384e-04 - val_loss: 0.0107
# Epoch 127/150
# 45/45 [==============================] - 4s 81ms/step - loss: 1.2273e-04 - val_loss: 0.0118
# Epoch 128/150
# 45/45 [==============================] - 4s 87ms/step - loss: 1.2644e-04 - val_loss: 0.0101
# Epoch 129/150
# 45/45 [==============================] - 5s 99ms/step - loss: 1.2625e-04 - val_loss: 0.0115
# Epoch 130/150
# 45/45 [==============================] - 4s 81ms/step - loss: 1.2867e-04 - val_loss: 0.0147
# Epoch 131/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1502e-04 - val_loss: 0.0117
# Epoch 132/150
# 45/45 [==============================] - 5s 110ms/step - loss: 1.3046e-04 - val_loss: 0.0085
# Epoch 133/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2419e-04 - val_loss: 0.0126
# Epoch 134/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1401e-04 - val_loss: 0.0111
# Epoch 135/150
# 45/45 [==============================] - 5s 112ms/step - loss: 1.0912e-04 - val_loss: 0.0124
# Epoch 136/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.1480e-04 - val_loss: 0.0126
# Epoch 137/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.1998e-04 - val_loss: 0.0109
# Epoch 138/150
# 45/45 [==============================] - 4s 100ms/step - loss: 1.3646e-04 - val_loss: 0.0077
# Epoch 139/150
# 45/45 [==============================] - 4s 89ms/step - loss: 1.4593e-04 - val_loss: 0.0114
# Epoch 140/150
# 45/45 [==============================] - 4s 81ms/step - loss: 1.2440e-04 - val_loss: 0.0116
# Epoch 141/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.2095e-04 - val_loss: 0.0093
# Epoch 142/150
# 45/45 [==============================] - 5s 107ms/step - loss: 1.1124e-04 - val_loss: 0.0145
# Epoch 143/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2063e-04 - val_loss: 0.0123
# Epoch 144/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.2585e-04 - val_loss: 0.0119
# Epoch 145/150
# 45/45 [==============================] - 5s 110ms/step - loss: 1.4088e-04 - val_loss: 0.0082
# Epoch 146/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2908e-04 - val_loss: 0.0113
# Epoch 147/150
# 45/45 [==============================] - 4s 79ms/step - loss: 1.2269e-04 - val_loss: 0.0117
# Epoch 148/150
# 45/45 [==============================] - 5s 104ms/step - loss: 1.3793e-04 - val_loss: 0.0087
# Epoch 149/150
# 45/45 [==============================] - 4s 85ms/step - loss: 1.2031e-04 - val_loss: 0.0076
# Epoch 150/150
# 45/45 [==============================] - 4s 80ms/step - loss: 1.3505e-04 - val_loss: 0.0098
# Fitting to BIDU
# Epoch 1/150
# 45/45 [==============================] - 5s 111ms/step - loss: 6.0426e-04 - val_loss: 0.0030
# Epoch 2/150
# 45/45 [==============================] - 4s 79ms/step - loss: 6.1867e-04 - val_loss: 0.0080
# Epoch 3/150
# 45/45 [==============================] - 4s 80ms/step - loss: 5.2829e-04 - val_loss: 0.0035
# Epoch 4/150
# ...
# Epoch 150/150
# 45/45 [==============================] - 4s 89ms/step - loss: 6.2645e-05 - val_loss: 0.0039
# Fitting to TSLA
# Epoch 1/150
# 45/45 [==============================] - 5s 113ms/step - loss: 4.6970e-04 - val_loss: 0.0068
# Epoch 2/150
# 45/45 [==============================] - 4s 89ms/step - loss: 4.5658e-04 - val_loss: 0.0033
# Epoch 3/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.3977e-04 - val_loss: 0.0047
# Epoch 4/150
# 45/45 [==============================] - 5s 119ms/step - loss: 3.6230e-04 - val_loss: 0.0042
# Epoch 5/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.7352e-04 - val_loss: 0.0039
# Epoch 6/150
# 45/45 [==============================] - 4s 89ms/step - loss: 3.6021e-04 - val_loss: 0.0021
# Epoch 7/150
# 45/45 [==============================] - 5s 119ms/step - loss: 3.4083e-04 - val_loss: 0.0044
# Epoch 8/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.9612e-04 - val_loss: 0.0038
# Epoch 9/150
# 45/45 [==============================] - 4s 89ms/step - loss: 3.0423e-04 - val_loss: 0.0040
# Epoch 10/150
# 45/45 [==============================] - 5s 121ms/step - loss: 2.9203e-04 - val_loss: 0.0013
# Epoch 11/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.6927e-04 - val_loss: 0.0031
# Epoch 12/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.8649e-04 - val_loss: 0.0018
# Epoch 13/150
# 45/45 [==============================] - 5s 120ms/step - loss: 3.2719e-04 - val_loss: 0.0034
# Epoch 14/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.7908e-04 - val_loss: 0.0027
# Epoch 15/150
# 45/45 [==============================] - 4s 88ms/step - loss: 3.3221e-04 - val_loss: 0.0035
# Epoch 16/150
# 45/45 [==============================] - 5s 122ms/step - loss: 2.8528e-04 - val_loss: 0.0046
# Epoch 17/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.9228e-04 - val_loss: 0.0028
# Epoch 18/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.1803e-04 - val_loss: 0.0042
# Epoch 19/150
# 45/45 [==============================] - 5s 122ms/step - loss: 3.1388e-04 - val_loss: 0.0036
# Epoch 20/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.9237e-04 - val_loss: 0.0040
# Epoch 21/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.7967e-04 - val_loss: 0.0034
# Epoch 22/150
# 45/45 [==============================] - 5s 115ms/step - loss: 2.9867e-04 - val_loss: 0.0029
# Epoch 23/150
# 45/45 [==============================] - 4s 93ms/step - loss: 3.0907e-04 - val_loss: 0.0046
# Epoch 24/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.1780e-04 - val_loss: 0.0037
# Epoch 25/150
# 45/45 [==============================] - 5s 108ms/step - loss: 2.6102e-04 - val_loss: 0.0031
# Epoch 26/150
# 45/45 [==============================] - 4s 96ms/step - loss: 2.9992e-04 - val_loss: 0.0021
# Epoch 27/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.3714e-04 - val_loss: 0.0031
# Epoch 28/150
# 45/45 [==============================] - 5s 109ms/step - loss: 2.9457e-04 - val_loss: 0.0034
# Epoch 29/150
# 45/45 [==============================] - 5s 99ms/step - loss: 2.9352e-04 - val_loss: 0.0046
# Epoch 30/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.7833e-04 - val_loss: 0.0048
# Epoch 31/150
# 45/45 [==============================] - 6s 138ms/step - loss: 2.7453e-04 - val_loss: 0.0045
# Epoch 32/150
# 45/45 [==============================] - 4s 98ms/step - loss: 3.1239e-04 - val_loss: 0.0022
# Epoch 33/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.8859e-04 - val_loss: 0.0042
# Epoch 34/150
# 45/45 [==============================] - 5s 109ms/step - loss: 2.8871e-04 - val_loss: 0.0034
# Epoch 35/150
# 45/45 [==============================] - 5s 99ms/step - loss: 2.7852e-04 - val_loss: 0.0041
# Epoch 36/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.7876e-04 - val_loss: 0.0029
# Epoch 37/150
# 45/45 [==============================] - 5s 107ms/step - loss: 2.7371e-04 - val_loss: 0.0045
# Epoch 38/150
# 45/45 [==============================] - 5s 99ms/step - loss: 2.7813e-04 - val_loss: 0.0037
# Epoch 39/150
# 45/45 [==============================] - 4s 90ms/step - loss: 3.0395e-04 - val_loss: 0.0036
# Epoch 40/150
# 45/45 [==============================] - 5s 104ms/step - loss: 2.8772e-04 - val_loss: 0.0022
# Epoch 41/150
# 45/45 [==============================] - 5s 103ms/step - loss: 2.8396e-04 - val_loss: 0.0043
# Epoch 42/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.8183e-04 - val_loss: 0.0036
# Epoch 43/150
# 45/45 [==============================] - 5s 102ms/step - loss: 2.8516e-04 - val_loss: 0.0033
# Epoch 44/150
# 45/45 [==============================] - 5s 105ms/step - loss: 2.9723e-04 - val_loss: 0.0050
# Epoch 45/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.7242e-04 - val_loss: 0.0034
# Epoch 46/150
# 45/45 [==============================] - 5s 102ms/step - loss: 2.7730e-04 - val_loss: 0.0037
# Epoch 47/150
# 45/45 [==============================] - 5s 109ms/step - loss: 2.7118e-04 - val_loss: 0.0042
# Epoch 48/150
# 45/45 [==============================] - 4s 92ms/step - loss: 3.6243e-04 - val_loss: 0.0031
# Epoch 49/150
# 45/45 [==============================] - 4s 98ms/step - loss: 2.7471e-04 - val_loss: 0.0029
# Epoch 50/150
# 45/45 [==============================] - 5s 109ms/step - loss: 2.6074e-04 - val_loss: 0.0040
# Epoch 51/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.7088e-04 - val_loss: 0.0028
# Epoch 52/150
# 45/45 [==============================] - 4s 99ms/step - loss: 2.6566e-04 - val_loss: 0.0029
# Epoch 53/150
# 45/45 [==============================] - 5s 108ms/step - loss: 2.6910e-04 - val_loss: 0.0042
# Epoch 54/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.7737e-04 - val_loss: 0.0040
# Epoch 55/150
# 45/45 [==============================] - 4s 94ms/step - loss: 2.7612e-04 - val_loss: 0.0040
# Epoch 56/150
# 45/45 [==============================] - 5s 114ms/step - loss: 2.5971e-04 - val_loss: 0.0040
# Epoch 57/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.6308e-04 - val_loss: 0.0026
# Epoch 58/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.9065e-04 - val_loss: 0.0027
# Epoch 59/150
# 45/45 [==============================] - 5s 117ms/step - loss: 2.8610e-04 - val_loss: 0.0029
# Epoch 60/150
# 45/45 [==============================] - 4s 88ms/step - loss: 2.7146e-04 - val_loss: 0.0028
# Epoch 61/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.7268e-04 - val_loss: 0.0037
# Epoch 62/150
# 45/45 [==============================] - 5s 121ms/step - loss: 2.7647e-04 - val_loss: 0.0048
# Epoch 63/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.6803e-04 - val_loss: 0.0027
# Epoch 64/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.6425e-04 - val_loss: 0.0046
# Epoch 65/150
# 45/45 [==============================] - 5s 119ms/step - loss: 2.9772e-04 - val_loss: 0.0033
# Epoch 66/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.8191e-04 - val_loss: 0.0041
# Epoch 67/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.8032e-04 - val_loss: 0.0037
# Epoch 68/150
# 45/45 [==============================] - 6s 125ms/step - loss: 2.9859e-04 - val_loss: 0.0034
# Epoch 69/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.8445e-04 - val_loss: 0.0032
# Epoch 70/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.6267e-04 - val_loss: 0.0029
# Epoch 71/150
# 45/45 [==============================] - 5s 121ms/step - loss: 2.5745e-04 - val_loss: 0.0030
# Epoch 72/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.7754e-04 - val_loss: 0.0040
# Epoch 73/150
# 45/45 [==============================] - 5s 118ms/step - loss: 2.8094e-04 - val_loss: 0.0018
# Epoch 74/150
# 45/45 [==============================] - 5s 119ms/step - loss: 2.6861e-04 - val_loss: 0.0025
# Epoch 75/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.7516e-04 - val_loss: 0.0021
# Epoch 76/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.7094e-04 - val_loss: 0.0033
# Epoch 77/150
# 45/45 [==============================] - 5s 119ms/step - loss: 2.6924e-04 - val_loss: 0.0026
# Epoch 78/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.6300e-04 - val_loss: 0.0044
# Epoch 79/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.7846e-04 - val_loss: 0.0033
# Epoch 80/150
# 45/45 [==============================] - 5s 120ms/step - loss: 2.6117e-04 - val_loss: 0.0027
# Epoch 81/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.9469e-04 - val_loss: 0.0047
# Epoch 82/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.9031e-04 - val_loss: 0.0034
# Epoch 83/150
# 45/45 [==============================] - 5s 119ms/step - loss: 2.5987e-04 - val_loss: 0.0027
# Epoch 84/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.6411e-04 - val_loss: 0.0024
# Epoch 85/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.7299e-04 - val_loss: 0.0033
# Epoch 86/150
# 45/45 [==============================] - 5s 118ms/step - loss: 2.6646e-04 - val_loss: 0.0031
# Epoch 87/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.6157e-04 - val_loss: 0.0028
# Epoch 88/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.8765e-04 - val_loss: 0.0039
# Epoch 89/150
# 45/45 [==============================] - 5s 118ms/step - loss: 2.8745e-04 - val_loss: 0.0020
# Epoch 90/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.7987e-04 - val_loss: 0.0030
# Epoch 91/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.7292e-04 - val_loss: 0.0039
# Epoch 92/150
# 45/45 [==============================] - 5s 120ms/step - loss: 2.7382e-04 - val_loss: 0.0038
# Epoch 93/150
# 45/45 [==============================] - 4s 88ms/step - loss: 2.6030e-04 - val_loss: 0.0031
# Epoch 94/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.6696e-04 - val_loss: 0.0042
# Epoch 95/150
# 45/45 [==============================] - 5s 121ms/step - loss: 2.6063e-04 - val_loss: 0.0041
# Epoch 96/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.9458e-04 - val_loss: 0.0020
# Epoch 97/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.5210e-04 - val_loss: 0.0037
# Epoch 98/150
# 45/45 [==============================] - 5s 114ms/step - loss: 2.9495e-04 - val_loss: 0.0027
# Epoch 99/150
# 45/45 [==============================] - 4s 93ms/step - loss: 2.6814e-04 - val_loss: 0.0022
# Epoch 100/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.7413e-04 - val_loss: 0.0040
# Epoch 101/150
# 45/45 [==============================] - 5s 110ms/step - loss: 2.6118e-04 - val_loss: 0.0023
# Epoch 102/150
# 45/45 [==============================] - 4s 97ms/step - loss: 2.6032e-04 - val_loss: 0.0033
# Epoch 103/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.8395e-04 - val_loss: 0.0013
# Epoch 104/150
# 45/45 [==============================] - 5s 103ms/step - loss: 3.2267e-04 - val_loss: 0.0033
# Epoch 105/150
# 45/45 [==============================] - 5s 103ms/step - loss: 2.7711e-04 - val_loss: 0.0028
# Epoch 106/150
# 45/45 [==============================] - 4s 89ms/step - loss: 3.0434e-04 - val_loss: 0.0038
# Epoch 107/150
# 45/45 [==============================] - 4s 98ms/step - loss: 2.7931e-04 - val_loss: 0.0023
# Epoch 108/150
# 45/45 [==============================] - 5s 111ms/step - loss: 2.6024e-04 - val_loss: 0.0050
# Epoch 109/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.9695e-04 - val_loss: 0.0034
# Epoch 110/150
# 45/45 [==============================] - 5s 100ms/step - loss: 2.6669e-04 - val_loss: 0.0037
# Epoch 111/150
# 45/45 [==============================] - 5s 110ms/step - loss: 2.8420e-04 - val_loss: 0.0037
# Epoch 112/150
# 45/45 [==============================] - 4s 89ms/step - loss: 2.8210e-04 - val_loss: 0.0019
# Epoch 113/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.8968e-04 - val_loss: 0.0040
# Epoch 114/150
# 45/45 [==============================] - 5s 118ms/step - loss: 2.7658e-04 - val_loss: 0.0037
# Epoch 115/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.8502e-04 - val_loss: 0.0027
# Epoch 116/150
# 45/45 [==============================] - 5s 115ms/step - loss: 2.7828e-04 - val_loss: 0.0034
# Epoch 117/150
# 45/45 [==============================] - 6s 123ms/step - loss: 3.1291e-04 - val_loss: 0.0037
# Epoch 118/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.9591e-04 - val_loss: 0.0033
# Epoch 119/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.4691e-04 - val_loss: 0.0047
# Epoch 120/150
# 45/45 [==============================] - 5s 119ms/step - loss: 2.4737e-04 - val_loss: 0.0031
# Epoch 121/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.7637e-04 - val_loss: 0.0053
# Epoch 122/150
# 45/45 [==============================] - 4s 91ms/step - loss: 3.4534e-04 - val_loss: 0.0030
# Epoch 123/150
# 45/45 [==============================] - 5s 122ms/step - loss: 2.8771e-04 - val_loss: 0.0040
# Epoch 124/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.5536e-04 - val_loss: 0.0030
# Epoch 125/150
# 45/45 [==============================] - 4s 91ms/step - loss: 3.0290e-04 - val_loss: 0.0022
# Epoch 126/150
# 45/45 [==============================] - 5s 120ms/step - loss: 2.6645e-04 - val_loss: 0.0031
# Epoch 127/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.6917e-04 - val_loss: 0.0043
# Epoch 128/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.7070e-04 - val_loss: 0.0031
# Epoch 129/150
# 45/45 [==============================] - 5s 117ms/step - loss: 2.5490e-04 - val_loss: 0.0032
# Epoch 130/150
# 45/45 [==============================] - 4s 94ms/step - loss: 2.6077e-04 - val_loss: 0.0030
# Epoch 131/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.7228e-04 - val_loss: 0.0030
# Epoch 132/150
# 45/45 [==============================] - 5s 113ms/step - loss: 2.5550e-04 - val_loss: 0.0031
# Epoch 133/150
# 45/45 [==============================] - 4s 96ms/step - loss: 2.5456e-04 - val_loss: 0.0030
# Epoch 134/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.6110e-04 - val_loss: 0.0023
# Epoch 135/150
# 45/45 [==============================] - 6s 126ms/step - loss: 2.5160e-04 - val_loss: 0.0023
# Epoch 136/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.8523e-04 - val_loss: 0.0032
# Epoch 137/150
# 45/45 [==============================] - 4s 92ms/step - loss: 2.5604e-04 - val_loss: 0.0035
# Epoch 138/150
# 45/45 [==============================] - 5s 115ms/step - loss: 2.6363e-04 - val_loss: 0.0032
# Epoch 139/150
# 45/45 [==============================] - 4s 93ms/step - loss: 2.4994e-04 - val_loss: 0.0030
# Epoch 140/150
# 45/45 [==============================] - 4s 90ms/step - loss: 2.4432e-04 - val_loss: 0.0035
# Epoch 141/150
# 45/45 [==============================] - 5s 119ms/step - loss: 2.5488e-04 - val_loss: 0.0025
# Epoch 142/150
# 45/45 [==============================] - 4s 96ms/step - loss: 3.1545e-04 - val_loss: 0.0031
# Epoch 143/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.8189e-04 - val_loss: 0.0030
# Epoch 144/150
# 45/45 [==============================] - 5s 116ms/step - loss: 2.6155e-04 - val_loss: 0.0031
# Epoch 145/150
# 45/45 [==============================] - 4s 94ms/step - loss: 2.5733e-04 - val_loss: 0.0033
# Epoch 146/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.5876e-04 - val_loss: 0.0030
# Epoch 147/150
# 45/45 [==============================] - 5s 117ms/step - loss: 2.7840e-04 - val_loss: 0.0032
# Epoch 148/150
# 45/45 [==============================] - 4s 92ms/step - loss: 3.1616e-04 - val_loss: 0.0028
# Epoch 149/150
# 45/45 [==============================] - 4s 91ms/step - loss: 2.8546e-04 - val_loss: 0.0030
# Epoch 150/150
# 45/45 [==============================] - 5s 110ms/step - loss: 2.6068e-04 - val_loss: 0.0036

# %%
for i in stockList:
  plt.rcParams['figure.figsize'] = (10,8)
  plt.plot(history.history['loss']) # tb
  plt.plot(history.history['val_loss'])
  plt.title('model loss of ' + i)
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
pred_result = {}
for i in stockList:
    y_true = scaler[i].inverse_transform(testset[i]["y"].reshape(-1,1))
    y_pred = scaler[i].inverse_transform(model.predict(testset[i]["X"]))
    pred_result[i] = {}
    pred_result[i]["True"] = y_true
    pred_result[i]["Pred"] = y_pred
    plt.figure(figsize=(8,8))
    plt.title("{}".format(i))
    plt.plot(y_true, color = 'b')
    plt.plot(y_pred, color = 'r')
    plt.xlabel("Time value (day)")
    plt.ylabel("Close value (point)")
    plt.legend(('prediction', 'actual'),loc='upper left', fontsize=12)
# Out:
# 14/14 [==============================] - 1s 20ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 19ms/step
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 20ms/step

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
for i in stockList:
    true = testset[i]["y"].reshape(-1,1)
    pred = model.predict(testset[i]["X"])
    errors = mean_squared_error(true,pred)
    errors2 = mean_squared_error(true, pred, squared=False)
    errors3 = mean_absolute_error(true, pred)
    errors4 = mean_absolute_error(true, pred)*100
# report error
    print('Test errors of ' + i + ":")
    print('mean squared error : %.8f MSE' % (errors))
    print('root mean squared error : %.8f RMSE' % (errors2))
    print('mean absolute error: %.8f MAE' %(errors3))
    print('mean absolute percentage error: %.8f MAPE' %(errors4) + "\n")
# Out:
# 14/14 [==============================] - 0s 32ms/step
# Test errors of AMZN:
# mean squared error : 0.00177991 MSE
# root mean squared error : 0.04218899 RMSE
# mean absolute error: 0.03246313 MAE
# mean absolute percentage error: 3.24631258 MAPE
#
# 14/14 [==============================] - 0s 33ms/step
# Test errors of NVDA:
# mean squared error : 0.00160620 MSE
# root mean squared error : 0.04007738 RMSE
# mean absolute error: 0.03104540 MAE
# mean absolute percentage error: 3.10454005 MAPE
#
# 14/14 [==============================] - 0s 31ms/step
# Test errors of AAPL:
# mean squared error : 0.00140281 MSE
# root mean squared error : 0.03745416 RMSE
# mean absolute error: 0.02804443 MAE
# mean absolute percentage error: 2.80444310 MAPE
#
# 14/14 [==============================] - 0s 20ms/step
# Test errors of BIDU:
# mean squared error : 0.00190523 MSE
# root mean squared error : 0.04364888 RMSE
# mean absolute error: 0.02837765 MAE
# mean absolute percentage error: 2.83776474 MAPE
#
# 14/14 [==============================] - 0s 21ms/step
# Test errors of GOOG:
# mean squared error : 0.00207609 MSE
# root mean squared error : 0.04556412 RMSE
# mean absolute error: 0.03297887 MAE
# mean absolute percentage error: 3.29788700 MAPE
#
# 14/14 [==============================] - 0s 21ms/step
# Test errors of INTC:
# mean squared error : 0.00593822 MSE
# root mean squared error : 0.07705986 RMSE
# mean absolute error: 0.04828356 MAE
# mean absolute percentage error: 4.82835635 MAPE
#
# 14/14 [==============================] - 0s 20ms/step
# Test errors of MSFT:
# mean squared error : 0.00201378 MSE
# root mean squared error : 0.04487510 RMSE
# mean absolute error: 0.03348262 MAE
# mean absolute percentage error: 3.34826244 MAPE
#
# 14/14 [==============================] - 0s 19ms/step
# Test errors of NFLX:
# mean squared error : 0.00238678 MSE
# root mean squared error : 0.04885469 RMSE
# mean absolute error: 0.03587223 MAE
# mean absolute percentage error: 3.58722280 MAPE
#
# 14/14 [==============================] - 0s 19ms/step
# Test errors of TCEHY:
# mean squared error : 0.00172983 MSE
# root mean squared error : 0.04159122 RMSE
# mean absolute error: 0.03187848 MAE
# mean absolute percentage error: 3.18784779 MAPE
#
# 14/14 [==============================] - 0s 22ms/step
# Test errors of TSLA:
# mean squared error : 0.00096765 MSE
# root mean squared error : 0.03110715 RMSE
# mean absolute error: 0.02495411 MAE
# mean absolute percentage error: 2.49541103 MAPE

# %%
df_new1 = {}
for i in stockList:
    df_new1[i] = {}
    df_new1[i]["Test"]  = df_[i].query('Date >= "2019-03-27"').reset_index(drop = False)

# %%
for i in stockList:
  y_pred = scaler[i].inverse_transform(model.predict(testset[i]["X"]))
  df_new1[i]["Test"].drop(columns=['Open', 'High','Low','Adj Close','Volume'],inplace = True)
  df_new1[i]["Test"].insert(2,"Predicted", y_pred)
# Out:
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 21ms/step
# 14/14 [==============================] - 0s 19ms/step
# 14/14 [==============================] - 0s 21ms/step

# %%
df_new1[i]["Test"]
# Out:
#            Date       Close   Predicted
# 0    2019-03-27   18.322001   22.261925
# 1    2019-03-28   18.574667   22.663044
# 2    2019-03-29   18.657333   22.909681
# 3    2019-04-01   19.278667   23.004892
# 4    2019-04-02   19.058666   23.538088
# ..          ...         ...         ...
# 438  2020-12-18  231.666672  202.909912
# 439  2020-12-21  216.619995  213.244522
# 440  2020-12-22  213.446671  201.170441
# 441  2020-12-23  215.326660  197.322357
# 442  2020-12-24  220.589996  200.218704
#
# [443 rows x 3 columns]

# %%
for i in stockList:
  # y_true = scaler[i].inverse_transform(testset[i]["y"].reshape(-1,1))
  # y_pred = scaler[i].inverse_transform(model.predict(testset[i]["X"]))
  df_pred = pd.DataFrame(data = df_new1[i]["Test"])
  df_pred.to_csv(i + "_output.csv")
